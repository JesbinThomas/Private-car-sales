# %%
#import libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
# %matplotlib inline
from sklearn import tree, preprocessing
from sklearn.model_selection import train_test_split
import sklearn.ensemble as ske
from sklearn.ensemble import GradientBoostingClassifier

#setting working directory
os.getcwd()

#loading dataset
Carsales_df= pd.read_csv("Car_sales.csv")

# %%
Carsales_df= pd.read_csv("Car_sales.csv")

# %%
# Import the pandas library
import pandas as pd
  
# Read Car_sales.csv into a DataFrame
df = pd.read_csv("Car_sales.csv")
  
# Prints no. of rows and columns of a DataFrame
df.shape
# Out:
# (157, 16)

# %%
# Prints the first 5 rows of a DataFrame as default
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
Carsales_df.groupby('Manufacturer').mean()
# Out:
#               Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# Manufacturer
# Acura                  19.751250            21.046250           30.633333
# Audi                   13.519000            28.270000           39.980000
# BMW                    15.501667            32.400000           33.096667
# Buick                  60.504750            14.941250           26.781250
# Cadillac               22.435600            23.393750           40.254000
# Chevrolet              61.596111            13.230625           20.022778
# Chrysler               28.817286            14.961667           23.430833
# Dodge                  82.740818            16.850500           24.213636
# Ford                  183.875909            12.960000           21.047273
# Honda                 118.534800            15.557000           20.277000
# Hyundai                45.775333             7.531667           12.165667
# ...

# %%
Carsales_df.count()
# Out:
# Manufacturer           157
# Model                  157
# Sales_in_thousands     157
# __year_resale_value    121
# Vehicle_type           157
# Price_in_thousands     155
# Engine_size            156
# Horsepower             156
# Wheelbase              156
# Width                  156
# Length                 156
# Curb_weight            155
# Fuel_capacity          156
# Fuel_efficiency        154
# Latest_Launch          157
# Power_perf_factor      155
# dtype: int64

# %%
Carsales_df.groupby('Model').mean()
# Out:
#           Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# Model
# 3-Sep                 12.115                  NaN              26.100
# 3000GT                 0.110               20.940              25.450
# 300M                  30.696                  NaN              29.185
# 323i                  19.747                  NaN              26.990
# 328i                   9.231               28.675              33.400
# ...                      ...                  ...                 ...
# Viper                  0.916               58.470              69.725
# Voyager               24.155               12.025              18.850
# Windstar             155.787               13.175              21.410
# Wrangler              55.557               13.475              14.460
# Xterra                54.158                  NaN              22.799
#
#           Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# Model
# ...

# %%
Carsales_df.groupby('Width').mean()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# Width
# 62.6            21.855000             5.160000            9.235000
# 65.7            41.184000             5.860000            9.699000
# 66.4            36.796333            10.193333           12.503333
# 66.5            60.933750            12.441667           16.423250
# 66.7            50.735667            12.734167           16.822167
# ...                   ...                  ...                 ...
# 78.7           125.338000            23.575000           36.135000
# 78.8            23.902500            14.467500           19.945000
# 79.1           540.561000            15.075000           26.935000
# 79.3           227.061000            15.060000           19.460000
# 79.9            22.925000                  NaN           42.660000
#
#        Engine_size  Horsepower  Wheelbase      Length  Curb_weight  \
# Width
# 62.6      1.000000   55.000000     93.100  149.400000     1.895000
# ...

# %%
Carsales_df['Model'].value_counts()
# Out:
# Neon          2
# 300M          1
# Mustang       1
# Sonata        1
# TL            1
#              ..
# Dakota        1
# Ram Pickup    1
# S40           1
# S70           1
# S-Type        1
# Name: Model, Length: 156, dtype: int64

# %%
Carsales_df[['Manufacturer', 'Model', 'Horsepower']]
# Out:
#     Manufacturer    Model  Horsepower
# 0          Acura  Integra       140.0
# 1          Acura       TL       225.0
# 2          Acura       CL       225.0
# 3          Acura       RL       210.0
# 4           Audi       A4       150.0
# ..           ...      ...         ...
# 152        Volvo      V40       160.0
# 153        Volvo      S70       168.0
# 154        Volvo      V70       168.0
# 155        Volvo      C70       236.0
# 156        Volvo      S80       201.0
#
# [157 rows x 3 columns]

# %%
Carsales_df_Vehicle_type = Carsales_df[Carsales_df['Manufacturer']=='BMW']

# %%
Carsales_df_Vehicle_type
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 7          BMW  323i              19.747                  NaN    Passenger
# 8          BMW  328i               9.231               28.675    Passenger
# 9          BMW  528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 7               26.99          2.5       170.0      107.3   68.4   176.0
# 8               33.40          2.8       193.0      107.3   68.5   176.0
# 9               38.90          2.8       193.0      111.4   70.9   188.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 7        3.179           16.6             26.0     6/28/2011
# 8        3.197           16.6             24.0     1/29/2012
# 9        3.472           18.5             25.0      4/4/2011
#
#    Power_perf_factor
# 7          71.191207
# 8          81.877069
# 9          83.998724

# %%
Carsales_df_Vehicle_type = Carsales_df[Carsales_df['Manufacturer']=='Hyundai']

# %%
Carsales_df_Vehicle_type
# Out:
#    Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 62      Hyundai   Accent              41.184                5.860
# 63      Hyundai  Elantra              66.692                7.825
# 64      Hyundai   Sonata              29.450                8.910
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 62    Passenger               9.699          1.5        92.0       96.1
# 63    Passenger              11.799          2.0       140.0      100.4
# 64    Passenger              14.999          2.4       148.0      106.3
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 62   65.7   166.7        2.240           11.9             31.0     9/10/2012
# 63   66.9   174.0        2.626           14.5             27.0    11/15/2011
# 64   71.6   185.4        3.072           17.2             25.0     6/14/2012
#
#     Power_perf_factor
# 62          36.672284
# 63          54.590045
# 64          58.758249

# %%
Carsales_df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
Carsales_df.Wheelbase.plot()
# Out:
# <AxesSubplot:>

# %%
Carsales_df.Model.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-7e2bb1deeee9> in <module>
# ----> 1 Carsales_df.Model.plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     276     def generate(self):
# ...

# %%
Carsales_df.Horsepower.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline

df = pd.read_csv ('Car_sales.csv')

sums = df.groupby(df["Manufacturer"])["Horsepower"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
plt.bar(x=Carsales_df['Model'],
 
        height=Carsales_df['Price_in_thousands'])
# Out:
# <BarContainer object of 157 artists>

# %%
Carsales_df.boxplot('Horsepower')
# Out:
# <AxesSubplot:>

# %%
Carsales_df.boxplot('Sales_in_thousands')
# Out:
# <AxesSubplot:>
